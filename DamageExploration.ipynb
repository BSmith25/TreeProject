# %%
# %run ImportData.ipynb

# %%
data_with_falls_damage.head()
# Out:
#    Unique Key_x          Created Date_x           Closed Date_x Agency_x  \
# 0    42990576.0  06/16/2019 11:19:28 AM  06/22/2019 10:42:11 PM      DPR
# 1    21153655.0  08/30/2011 04:10:41 PM  09/03/2011 04:37:28 PM      DPR
# 2    42992416.0  06/16/2019 10:11:03 AM  06/22/2019 11:14:50 PM      DPR
# 3    42992416.0  06/16/2019 10:11:03 AM  06/22/2019 11:14:50 PM      DPR
# 4    21153655.0  08/30/2011 04:10:41 PM  09/03/2011 04:37:28 PM      DPR
#
#           Complaint Type_x                    Descriptor_x Location Type_x  \
# 0  Overgrown Tree/Branches           Dead Branches in Tree          Street
# 1             Damaged Tree  Tree Alive - in Poor Condition          Street
# 2             Damaged Tree    Branch Cracked and Will Fall          Street
# 3             Damaged Tree    Branch Cracked and Will Fall          Street
# 4             Damaged Tree  Tree Alive - in Poor Condition          Street
#
# ...

# %%
data_with_falls_damage.columns
# Out:
# Index(['Unique Key_x', 'Created Date_x', 'Closed Date_x', 'Agency_x',
#        'Complaint Type_x', 'Descriptor_x', 'Location Type_x',
#        'Incident Address_x', 'Latitude_x', 'Longitude_x', 'Unique Key_y',
#        'Created Date_y', 'Closed Date_y', 'Agency_y', 'Complaint Type_y',
#        'Descriptor_y', 'Location Type_y', 'Incident Address_y', 'Latitude_y',
#        'Longitude_y', 'address', 'created_at', 'curb_loc', 'guards', 'health',
#        'latitude', 'longitude', 'problems', 'root_grate', 'root_other',
#        'root_stone', 'sidewalk', 'spc_common', 'status', 'steward', 'tree_dbh',
#        'tree_id', 'trnk_light', 'trnk_other', 'trnk_wire', 'zipcode', 'Fall',
#        'Damage'],
#       dtype='object')

# %%
data_with_falls_damage['Descriptor_x'].unique()
# Out:
# array(['Dead Branches in Tree', 'Tree Alive - in Poor Condition',
#        'Branch Cracked and Will Fall', 'Planted More Than 2 Years Ago',
#        'Planted Less Than 2 Years Ago', 'Dead/Dying Tree',
#        'Tree Leaning/Uprooted', 'Branches Damaged', 'Trunk Damaged',
#        'Tree Trunk Split', 'Roots Damaged', 'Dead Animal', nan],
#       dtype=object)
